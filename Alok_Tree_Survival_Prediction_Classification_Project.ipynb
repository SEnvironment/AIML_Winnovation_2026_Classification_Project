# %% [markdown]
# <a href="https://colab.research.google.com/github/SEnvironment/AIML_Winnovation_2026_Classification_Project/blob/main/Alok_Tree_Survival_Prediction_Classification_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Tree Survival prediction

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# ##### **Team Member -** Alok
# **Class** - CSE-DS
#
#
# **Batch** - 2024-28

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Tree Survival Dataset is designed to analyze and predict the survival status of tree seedlings based on various environmental, biological, and ecological factors. This dataset is well suited for a classification machine learning project, where the objective is to classify whether a tree survives or does not survive under different growing conditions. Such predictive models can help ecologists, forest managers, and environmental researchers make informed decisions regarding forest conservation, biodiversity management, and plantation planning.
#
# The dataset contains 2,783 observations and 24 attributes, representing different characteristics of individual trees. Each record corresponds to a single tree seedling and includes information related to its species, location, soil conditions, light availability, fungal associations, and biochemical properties. The dataset combines both categorical variables (such as Species, Soil Type, Light Category, Mycorrhizal Type, and Plot information) and numerical variables (such as Light_ISF, Phenolics, Lignin, NSC, and Time), making it ideal for exploring feature engineering and classification techniques.
#
# The primary target variable for this project is Alive, which indicates whether a tree remained alive after the observation period. In cases where the Alive column is unavailable or contains missing values, the Event variable can also be used as the target by interpreting survival events appropriately. The classification task involves predicting the survival outcome using the remaining environmental and biological features.
#
# Several factors in the dataset contribute significantly to tree survival. Light_ISF measures the amount of light available to the tree, while Light_Cat categorizes light intensity into different levels. Soil represents different soil conditions, which influence nutrient availability and water retention. Species identifies the tree species, allowing the model to capture species-specific survival patterns. Biological variables such as AMF (Arbuscular Mycorrhizal Fungi), EMF (Ectomycorrhizal Fungi), Phenolics, Lignin, and NSC (Non-Structural Carbohydrates) provide insights into the physiological and ecological characteristics that affect growth and resilience. Additional variables such as Adult, Sterile, Conspecific, and Myco further describe the ecological interactions influencing survival.
#
# Before building the classification model, the dataset requires preprocessing steps such as handling missing values, encoding categorical variables, scaling numerical features where necessary, and selecting relevant predictors. Exploratory Data Analysis (EDA) can be performed to understand class distribution, feature relationships, and correlations between variables. Data visualization techniques such as histograms, bar charts, heatmaps, and boxplots can help identify patterns and detect potential outliers.
#
# Various machine learning classification algorithms can be applied to this dataset, including Logistic Regression, Decision Tree, Random Forest, Support Vector Machine (SVM), K-Nearest Neighbors (KNN), Naïve Bayes, Gradient Boosting, and XGBoost. The performance of these models can be evaluated using metrics such as Accuracy, Precision, Recall, F1-Score, Confusion Matrix, and ROC-AUC Score. Cross-validation and hyperparameter tuning can further improve model performance and generalization.
#
# Overall, this classification project demonstrates how machine learning can be used to predict tree survival based on ecological and environmental data. By identifying the most influential factors affecting survival, the model provides valuable insights into forest ecosystem dynamics and supports evidence-based decision-making in conservation and sustainable forest management. The project also offers practical experience in data preprocessing, feature engineering, model development, evaluation, and interpretation, making it an excellent application of supervised machine learning techniques in environmental science.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/SEnvironment/AIML_Winnovation_2026_Classification_Project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Build a machine learning classification model to predict tree survival based on environmental and biological characteristics.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score,classification_report

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
ts = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DATA SETs/Tree_Survival DataSet.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
ts.head()
# Out:
#      No  Plot Subplot         Species  Light_ISF Light_Cat  Core  \
# 0   126     1       C  Acer saccharum      0.106       Med  2017
# 1    11     1       C    Quercus alba      0.106       Med  2017
# 2    12     1       C   Quercus rubra      0.106       Med  2017
# 3  2823     7       D  Acer saccharum      0.080       Med  2016
# 4  5679    14       A  Acer saccharum      0.060       Low  2017
#
#               Soil Adult      Sterile  ...    AMF    EMF Phenolics Lignin  \
# 0  Prunus serotina     I  Non-Sterile  ...  22.00    NaN     -0.56  13.86
# 1    Quercus rubra   970  Non-Sterile  ...  15.82  31.07      5.19  20.52
# 2  Prunus serotina     J  Non-Sterile  ...  24.45  28.19      3.36  24.74
# 3  Prunus serotina     J  Non-Sterile  ...  22.23    NaN     -0.71  14.29
# 4  Prunus serotina   689  Non-Sterile  ...  21.15    NaN     -0.58  10.85
#
#      NSC  Census   Time  Event  Harvest  Alive
# 0  12.15       4   14.0    1.0      NaN    NaN
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
ts.shape
# Out:
# (2783, 24)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2783 entries, 0 to 2782
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No           2783 non-null   int64
#  1   Plot         2783 non-null   int64
#  2   Subplot      2783 non-null   object
#  3   Species      2783 non-null   object
#  4   Light_ISF    2783 non-null   float64
#  5   Light_Cat    2783 non-null   object
#  6   Core         2783 non-null   int64
#  7   Soil         2783 non-null   object
#  8   Adult        2783 non-null   object
#  9   Sterile      2783 non-null   object
#  10  Conspecific  2783 non-null   object
#  11  Myco         2783 non-null   object
#  12  SoilMyco     2783 non-null   object
#  13  PlantDate    2783 non-null   object
#  14  AMF          2783 non-null   float64
#  15  EMF          1283 non-null   float64
#  16  Phenolics    2783 non-null   float64
#  17  Lignin       2783 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
ts.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
ts.isnull().sum()
# Out:
# No                0
# Plot              0
# Subplot           0
# Species           0
# Light_ISF         0
# Light_Cat         0
# Core              0
# Soil              0
# Adult             0
# Sterile           0
# Conspecific       0
# Myco              0
# SoilMyco          0
# PlantDate         0
# AMF               0
# EMF            1500
# Phenolics         0
# Lignin            0
# NSC               0
# Census            0
# Time              0
# Event             1
# Harvest        2079
# Alive          2292
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(15,10))
sns.heatmap(ts.isna())
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# By this we know that in our data we have total 4 column which contain null values are EMF,Events,Harvest,Alive.
#
# In which we need to deal with the null value in EMF, Harvest and Alive and removing the null value of Event because it have only one null value.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
ts.columns
# Out:
# Index(['No', 'Plot', 'Subplot', 'Species', 'Light_ISF', 'Light_Cat', 'Core',
#        'Soil', 'Adult', 'Sterile', 'Conspecific', 'Myco', 'SoilMyco',
#        'PlantDate', 'AMF', 'EMF', 'Phenolics', 'Lignin', 'NSC', 'Census',
#        'Time', 'Event', 'Harvest', 'Alive'],
#       dtype='object')

# %%
# Dataset Describe
ts.describe()
# Out:
#                 No         Plot    Light_ISF         Core          AMF  \
# count  2783.000000  2783.000000  2783.000000  2783.000000  2783.000000
# mean   3914.513834     9.561624     0.085707  2016.648940    20.553069
# std    2253.515063     5.203659     0.025638     0.477387    12.309587
# min       3.000000     1.000000     0.032000  2016.000000     0.000000
# 25%    1971.000000     5.000000     0.066000  2016.000000    13.400000
# 50%    3932.000000    10.000000     0.082000  2017.000000    18.000000
# 75%    5879.000000    14.000000     0.100000  2017.000000    24.445000
# max    7772.000000    18.000000     0.161000  2017.000000   100.000000
#
#               EMF    Phenolics       Lignin          NSC       Census  \
# count  1283.00000  2783.000000  2783.000000  2783.000000  2783.000000
# mean     26.47675     1.933105    15.759792    14.219641    15.282070
# std      16.63689     1.969842     6.779607     4.298271     9.166555
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. No: Seedling unique ID number.
# 2. Plot: Number of the field plot the seedling was planted in (1-18).
# 3. Subplot: Subplot within the main plot the seedling was planted in. Broken into 5 subplots (1 per corner, plus 1 in the middle) (A-E).
# 4. Species: Includes Acer saccharum, Prunus serotina, Quercus alba, and Quercus rubra.
# 5. Light ISF: Light level quantified with HemiView software. Represents the amount of light reaching each subplot at a height of 1m.
# 6. Light Cat: Categorical light level created by splitting the range of Light_ISF values into three bins (low, med, high).
# 7. Core: Year the soil core was removed from the field.
# 8. Soil: Species from which the soil core was taken. Includes all species, plus Acer rubrum, Populus grandidentata, and a sterilized conspecific for each species.
# 9. Adult: Individual tree that soil was taken from. Up to 6 adults per species. Used as a random effect in analyses.
# 10. Sterile: Whether the soil was sterilized or not.
# Conspecific: Whether the soil was conspecific, heterospecific, or sterilized conspecific.
# 11. Myco: Mycorrhizal type of the seedling species (AMF or EMF).
# 12. SoilMyco: Mycorrhizal type of the species culturing the soil (AMF or EMF).
# 13. PlantDate: The date that seedlings were planted in the field pots.
# 14. AMF: Percent arbuscular mycorrhizal fungi colonization on the fine roots of harvested seedlings.
# 15. EMF: Percent ectomycorrhizal fungi colonization on the root tips of harvested seedlings.
# 16. Phenolics: Calculated as nmol Gallic acid equivalents per mg dry extract (see manuscript for detailed methods).
# 17. NSC: Calculated as percent dry mass nonstructural carbohydrates (see manuscript for detailed methods).
# 18. Lignin: Calculated as percent dry mass lignin (see manuscript for detailed methods).
# 19. Census: The census number at which time the seedling died or was harvested.
# 20. Time: The number of days at which time the seedling died or was harvested.
# 21. Event: Used for survival analysis to indicate status of each individual seedling at a given time (above)
# 0 = harvested or experiment ended
# 1 = dead
# 22. Harvest: Indicates whether the seedling was harvested for trait measurement.
# 23. Alive: Indicates if the seedling was alive at the end of the second growing season. "X" in this field indicates alive status.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
col = ts.columns.to_list()
for  i in col:
  print(f'{i} = {ts[i].unique()} \n')
# Out:
# No = [ 126   11   12 ... 7306 7771 7401]
#
# Plot = [ 1  7 14  2  3  4  5  6  8  9 10 11 12 13 15 16 17 18]
#
# Subplot = ['C' 'D' 'A' 'B' 'E']
#
# Species = ['Acer saccharum' 'Quercus alba' 'Quercus rubra' 'Prunus serotina']
#
# Light_ISF = [0.106 0.08  0.06  0.108 0.107 0.1   0.098 0.083 0.097 0.082 0.103 0.095
#  0.087 0.078 0.079 0.071 0.076 0.118 0.073 0.086 0.077 0.091 0.065 0.092
#  0.09  0.075 0.061 0.066 0.063 0.074 0.051 0.072 0.055 0.068 0.05  0.047
#  0.035 0.032 0.052 0.093 0.053 0.059 0.11  0.122 0.133 0.111 0.105 0.141
#  0.14  0.148 0.161 0.138 0.094]
#
# Light_Cat = ['Med' 'Low' 'High']
#
# Core = [2017 2016]
#
# Soil = ['Prunus serotina' 'Quercus rubra' 'Acer rubrum' 'Populus grandidentata'
#  'Sterile' 'Acer saccharum' 'Quercus alba']
#
# Adult = ['I' '970' 'J' '689' '1332' '891' '1595' '1323' '394' '561' '1478' '1320'
#  '1454' '921' '984' '118' '1757' '1384' '1688' '961' '1715' '50' '1468'
#  '1201' '1386' '277' '415' '285' '275' '1205' '1330' '1297' '1326' 'H'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#Droping the null Value of Event Column.
ts.dropna(subset=['Event'], inplace=True)

#Replacing Null value of Alive to No.
ts['Alive']= ts['Alive'].fillna('No')

#Replacing Null Value of Harvest to No.
ts['Harvest']= ts['Harvest'].fillna('No')

#Replacing from null Value from the mode of EMF.
ts['EMF']= ts['EMF'].fillna(ts['EMF'].mode()[0])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **1- Data Overview**
#   * We have **2782** **rows** and **24** **columns** provided in the data.
#
#   * In the dataset we have **12 object** columns, **4 integer** and **8 integer**
#
# **2- Checking the null values**
#   * Fist we have **1500** null values in **EMF** column.
#
#   * We have **2079** null values in **Harvest** column. and it can be replaced with 'No'.
#
#   * we have **2292** null values in **Alive** column.Replacing nulls with 'No'.
#
#   * Also we have **1** null values in **Event** column.So, we droped that single Row.
#
# **3- Check Duplicate values in the dataset**
#
#   * we do not have any Duplicate values in the dataset.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
plt.figure(figsize=(6,5))
sns.countplot(x='Alive', data=ts)
plt.title('Distribution of Tree Survival')
plt.xlabel('Tree Survival')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is the most suitable visualization for displaying the frequency of each class in the target variable. It quickly shows whether the dataset is balanced or imbalanced, which is important before building a classification model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the number of surviving and non-surviving trees.
# It helps identify whether one class dominates the dataset.
# A balanced dataset generally leads to better classification performance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Knowing the survival distribution helps researchers estimate plantation success rates and determine whether intervention is needed to improve survival.
#
# Negative Growth (if any):
# If dead trees greatly outnumber surviving trees, it indicates poor environmental conditions or ineffective plantation management, requiring corrective actions.

# %% [markdown]
# #### Chart - 2

# %%
plt.figure(figsize=(10,6))
sns.countplot(y='Species', data=ts,
              order=ts['Species'].value_counts().index)
plt.title('Number of Trees by Species')
plt.xlabel('Count')
plt.ylabel('Species')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart makes it easier to compare the number of observations across multiple species, especially when there are many categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows the distribution of different tree species.
# Identifies the most and least represented species.
# Reveals whether the dataset is evenly distributed across species.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps forest managers understand which species are more commonly planted or studied, supporting better biodiversity planning.
#
# Negative Growth (if any):
# Overrepresentation of one species may reduce biodiversity and increase vulnerability to diseases or pests.

# %% [markdown]
# #### Chart - 3

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Species', hue='Alive', data=ts)
plt.xticks(rotation=0)
plt.title('Tree Survival by Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.legend(title='Alive')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart allows direct comparison of survival and mortality for each tree species.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some species have higher survival rates than others.
# Certain species appear more resistant to environmental conditions.
# Weak-performing species can be easily identified.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Selecting species with higher survival rates can improve reforestation success and reduce plantation costs.
#
# Negative Growth (if any):
# Species with consistently low survival rates may not be suitable for the studied environment.

# %% [markdown]
# #### Chart - 4

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Soil', data=ts)
plt.xticks(rotation=90)
plt.title('Distribution of Soil Types')
plt.xlabel('Soil Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart effectively compares the frequency of different soil types present in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Displays the number of observations in each soil category.
# Helps identify dominant soil conditions.
# Indicates whether data collection covered multiple soil environments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding soil distribution supports better land selection for future plantation projects.
#
# Negative Growth (if any):
# If one soil type dominates the dataset, model predictions may not generalize well to other soil conditions.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Soil', hue='Alive', data=ts)
plt.xticks(rotation = 90)
plt.title('Tree Survival Across Soil Types')
plt.xlabel('Soil Type')
plt.ylabel('Count')
plt.legend(title='Alive')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart clearly compares tree survival across different soil types, making it easy to identify which soils support better survival.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some soil types have noticeably higher survival rates.
# Other soils may be associated with greater mortality.
# Soil characteristics appear to influence tree growth and survival.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Forest managers can prioritize soil types that support healthier tree growth, improving plantation success and reducing resource wastage.
#
# Negative Growth (if any):
# If a particular soil type consistently shows poor survival, planting trees in those conditions may lead to higher losses unless soil quality is improved.

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='Light_Cat', data=ts)
plt.title('Distribution of Light Categories')
plt.xlabel('Light Category')
plt.ylabel('Number of Trees')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is ideal for comparing the number of trees under different light categories. It clearly shows how the observations are distributed across light conditions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It identifies the most common light category in the dataset.
# Shows whether trees were sampled equally under different light conditions.
# Highlights any imbalance in light exposure.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps forest managers understand which light conditions are most common and supports planning plantations based on appropriate sunlight availability.
#
# Negative Growth:
#
# If one light category dominates the dataset, the classification model may become biased toward that condition and perform poorly on underrepresented categories.

# %% [markdown]
# #### Chart - 7

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='Alive', y='Light_ISF', data=ts)
plt.title('Average Light Availability by Survival Status')
plt.xlabel('Alive')
plt.ylabel('Average Light_ISF')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart effectively compares the average light availability between surviving and non-surviving trees.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Compares average light received by alive and dead trees.
# Determines whether light availability influences survival.
# Helps identify the optimal light conditions for tree growth.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding optimal light conditions can improve plantation planning and increase survival rates.
#
# Negative Growth:
#
# Very low light availability may reduce photosynthesis, leading to poor tree growth and higher mortality.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(7,5))
sns.boxplot(x='Alive', y='Light_ISF', data=ts)
plt.title('Light_ISF Distribution by Survival Status')
plt.xlabel('Alive')
plt.ylabel('Light_ISF')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is useful for comparing the spread, median, and outliers of light availability for surviving and non-surviving trees.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Reveals variation in light availability.
# Detects outliers.
# Shows whether surviving trees generally receive more or less light.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps determine suitable light conditions that maximize tree survival.
#
# Negative Growth:
#
# Large variability or many outliers may indicate inconsistent environmental conditions affecting survival.

# %% [markdown]
# #### Chart - 9

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='Alive', y='Phenolics', data=ts)
plt.title('Average Phenolics Level by Survival Status')
plt.xlabel('Alive')
plt.ylabel('Average Phenolics')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart clearly compares the average phenolic content between surviving and dead trees.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows whether higher phenolic content is associated with better survival.
# Helps evaluate the defensive role of phenolics.
# Indicates possible biological differences between alive and dead trees.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Researchers can identify biochemical characteristics that improve resistance against environmental stress and diseases.
#
# Negative Growth:
#
# Lower phenolic levels may reduce natural defense mechanisms, increasing mortality.

# %% [markdown]
# #### Chart - 10

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='Alive', y='Lignin', data=ts)
plt.title('Average Lignin Level by Survival Status')
plt.xlabel('Alive')
plt.ylabel('Average Lignin')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart provides a straightforward comparison of the average lignin content between surviving and dead trees.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Compares lignin concentration across survival groups.
# Helps determine whether stronger structural tissue is associated with survival.
# Indicates the importance of lignin in tree health.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding lignin levels can help researchers select tree species that are more resistant to environmental stress and physical damage.
#
# Negative Growth:
#
# If dead trees consistently exhibit lower lignin levels, weaker structural integrity may contribute to higher mortality, suggesting a need for better species selection or environmental management.

# %% [markdown]
# #### Chart - 11

# %%
plt.figure(figsize=(6,5))
sns.barplot(x='Alive', y='NSC', data=ts)
plt.title('Average NSC by Survival Status')
plt.xlabel('Tree Survival')
plt.ylabel('Average NSC')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing the average NSC levels between surviving and non-surviving trees. It clearly highlights differences in energy reserves.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows whether surviving trees have higher carbohydrate reserves.
# Helps understand the relationship between stored energy and tree survival.
# Indicates if NSC is an important predictor for classification.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Trees with higher NSC levels generally have better energy reserves, helping forest managers identify healthier trees for plantation and conservation.
#
# Negative Growth:
#
# Lower NSC levels indicate poor energy storage, making trees more vulnerable to environmental stress and reducing survival rates.

# %% [markdown]
# #### Chart - 12

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Myco', hue='Alive', data=ts)
plt.title('Tree Survival by Mycorrhizal Type')
plt.xlabel('Mycorrhizal Type')
plt.ylabel('Number of Trees')
plt.legend(title='Alive')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart effectively compares the number of surviving and non-surviving trees across different mycorrhizal associations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows which mycorrhizal association has the highest survival.
# Identifies fungal relationships that support tree growth.
# Highlights biological factors influencing survival.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding beneficial fungal associations can improve reforestation success and increase plantation productivity.
#
# Negative Growth:
#
# Certain mycorrhizal types may show lower survival rates, indicating weaker nutrient exchange or unfavorable environmental conditions.

# %% [markdown]
# #### Chart - 13

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x='Light_ISF',
    y='NSC',
    hue='Alive',
    data=ts
)

plt.title('Light Availability vs NSC')
plt.xlabel('Light_ISF')
plt.ylabel('NSC')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot helps visualize the relationship between two numerical variables while distinguishing survival status using different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows whether increased light leads to higher NSC.
# Reveals clusters of surviving and non-surviving trees.
# Detects unusual observations (outliers).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps identify environmental conditions that maximize tree survival and supports better forest management strategies.
#
# Negative Growth:
#
# If surviving and dead trees overlap heavily, Light_ISF and NSC alone may not be sufficient predictors, requiring additional variables for accurate classification.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
plt.figure(figsize=(12,8))

numeric_ts = ts.select_dtypes(include=['number'])

sns.heatmap(numeric_ts.corr(),
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is one of the most effective tools for identifying relationships among numerical variables before building a machine learning model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Shows positive and negative correlations.
# Identifies highly correlated variables.
# Helps detect multicollinearity.
# Assists in feature selection.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Select only numerical columns
numeric_ts = ts[['Light_ISF', 'Phenolics', 'Lignin', 'NSC', 'Time']]

# Pair Plot
sns.pairplot(numeric_ts)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is an excellent exploratory data analysis (EDA) tool because it simultaneously visualizes the relationships between multiple numerical variables. It displays scatter plots for every pair of variables and histograms (or density plots) along the diagonal, making it easy to identify correlations, trends, clusters, and outliers before building a machine learning classification model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot reveals the relationships among numerical features such as Light_ISF, Phenolics, Lignin, NSC, and Time.
# It helps identify whether any variables are positively or negatively correlated.
# The diagonal plots show the distribution of each numerical feature and indicate whether the data is normally distributed or skewed.
# Scatter plots help detect clusters, unusual observations (outliers), and potential multicollinearity between variables.
# These insights assist in selecting the most relevant features for the classification model.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
